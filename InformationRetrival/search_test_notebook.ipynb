# %%
import json
import ast

# %%
import pandas as pd 
import json 
df = pd.read_csv("/Users/kishanmaladkar/mds/block5/week1/COLX_523_Project/milestone4/data/mturks_cleaned.csv")
with open("../data/data.json", "w") as f:
    json.dump(json.loads(df.reset_index(drop=True).to_json(orient='table')), f)

# with open("data.json", "r") as f:
#     print(json.loads(f.read()))

# %%
json.loads(df.to_json(orient='table'))
# Out:
# notator': 'Appetizer or side dish',
#    'third_annotator': 'Main course',
#    'most_common': 'Main course'},
#   {'index': 712,
#    'Input.document_url': 'The Best Ever Vegan Burger',
#    'first_annotator': 'Main course',
#    'second_annotator': 'Main course',
#    'third_annotator': 'Other',
#    'most_common': 'Main course'},
#   {'index': 713,
#    'Input.document_url': 'The Best Ever Vegan Mac N Cheese',
#    'first_annotator': 'Main course',
#    'second_annotator': 'Appetizer or side dish',
#    'third_annotator': 'Main course',
#    'most_common': 'Main course'},
#   {'index': 714,
#    'Input.document_url': 'The Best Gooey Salted Caramel Brownies',
#    'first_annotator': 'Dessert',
#    'second_annotator': 'Dessert',
#    'third_annotator': 'Dessert',
#    'most_common': 'Dessert'},
#   {'index': 715,
#    'Input.document_url': 'The Best Layered Lasagna',
#    'first_annotator': 'Main course',
#    'second_annotator': 'Main course',
# ...

# %%
with open("../data/data.json") as f:
    data = json.load(f)

# %%
data[0]
# Out:
# '{'
